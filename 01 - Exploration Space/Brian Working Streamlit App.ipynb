# %%
import streamlit as st
import pandas as pd
from datetime import datetime
import numpy as np

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (1.50.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\renai\appdata\roaming\python\python313\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.33.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\renai\appdata\roaming\python\python313\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.8.0)
# Requirement already satisfied: colorama in c:\users\renai\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\renai\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\renai\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\renai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('mergedTrainingData.csv')
df
# Out:
#       Unnamed: 0  week  season              Team          opponent  code  \
# 0              1    10    2021         Air Force              Army  2005
# 1              2    10    2021             Akron  Western Michigan  2006
# 2              3    10    2021           Alabama               LSU   333
# 3              4    10    2021           Arizona        California    12
# 4              5    10    2021     Arizona State               USC     9
# ...          ...   ...     ...               ...               ...   ...
# 5641        5642     9    2024     West Virginia           Arizona   277
# 5642        5643     9    2024  Western Kentucky    Kennesaw State    98
# 5643        5644     9    2024  Western Michigan        Kent State  2711
# 5644        5645     9    2024         Wisconsin        Penn State   275
# 5645        5646     9    2024           Wyoming        Utah State  2751
#
#              date win_loss     OT OT_num  ...  home_game           CONF  SOR  \
# 0      Sat, Nov 6        L   True         ...       True  Mountain West   33
# 1      Tue, Nov 9        L  False    NaN  ...      False            MAC  127
# 2      Sat, Nov 6        W  False    NaN  ...       True            SEC    2
# 3      Sat, Nov 6        W  False    NaN  ...       True         Pac-12  122
# 4      Sat, Nov 6        W  False    NaN  ...       True         Pac-12   49
# ...           ...      ...    ...    ...  ...        ...            ...  ...
# 5641  Sat, Oct 26        W  False    NaN  ...      False         Big 12   58
# 5642  Wed, Oct 30        W  False    NaN  ...       True           CUSA   84
# 5643  Sat, Oct 26        W  False    NaN  ...       True            MAC  103
# 5644  Sat, Oct 26        L  False    NaN  ...       True        Big Ten   55
# 5645  Sat, Oct 26        L  False    NaN  ...       True  Mountain West  119
#
#       FPI  SOS   GC  AVGWP AP_rank  opponent_rank  rank_change
# 0      66  110   24      6     NaN            NaN          0.0
# 1     128   67  118    125     NaN            NaN          0.0
# 2       2    1    2      3     3.0            NaN         -1.0
# 3     106   71  110    122     NaN            NaN          0.0
# 4      39   61   61     63     NaN            NaN          0.0
# ...   ...  ...  ...    ...     ...            ...          ...
# 5641   63   54   64     81     NaN            NaN          0.0
# 5642   99   80   77     56     NaN            NaN          0.0
# 5643  108   70  103     87     NaN            NaN          0.0
# 5644   47   32   41     76     NaN            3.0          0.0
# 5645  113   97  124    125     NaN            NaN          0.0
#
# [5646 rows x 26 columns]

# %%
df['season'].unique()
# Out:
# array([2021, 2022, 2023, 2024])

# %%
df['week'].value_counts()
# Out:
# week
# 12    477
# 11    465
# 10    464
# 13    462
# 5     458
# 4     447
# 9     443
# 8     440
# 6     428
# 7     423
# 3     407
# 2     362
# 14    282
# 15     68
# 16     13
# 18      4
# 17      3
# Name: count, dtype: int64

# %%
for i in df:
    print(i)
# Out:
# Unnamed: 0
# week
# season
# Team
# opponent
# code
# date
# win_loss
# OT
# OT_num
# pass
# rush
# rec
# points_allowed
# points_scored
# point_differential
# home_game
# CONF
# SOR
# FPI
# SOS
# GC
# AVGWP
# AP_rank
# opponent_rank
# rank_change

# %%
df['week'].unique()
# Out:
# array([10, 11, 12, 13, 14, 15, 16, 17, 18,  2,  3,  4,  5,  6,  7,  8,  9])

# %%
teams = df['Team'].unique()
teams
# Out:
# array(['Air Force', 'Akron', 'Alabama', 'Arizona', 'Arizona State',
#        'Arkansas', 'Army', 'Auburn', 'Ball State', 'Baylor',
#        'Boise State', 'Boston College', 'Bowling Green', 'Buffalo',
#        'Central Michigan', 'Charlotte', 'Cincinnati', 'Coastal Carolina',
#        'Colorado', 'Colorado State', 'Duke', 'East Carolina',
#        'Eastern Michigan', 'Florida', 'Florida Atlantic',
#        'Florida International', 'Florida State', 'Fresno State',
#        'Georgia', 'Georgia Southern', 'Georgia State', 'Georgia Tech',
#        "Hawai'i", 'Houston', 'Illinois', 'Indiana', 'Iowa', 'Iowa State',
#        'Kansas', 'Kansas State', 'Kent State', 'Kentucky', 'Liberty',
#        'Louisiana', 'Louisiana Tech', 'Louisville', 'LSU', 'Marshall',
#        'Maryland', 'Memphis', 'Miami', 'Miami (OH)', 'Michigan',
#        'Michigan State', 'Middle Tennessee', 'Minnesota',
#        'Mississippi State', 'Missouri', 'Navy', 'NC State', 'Nebraska',
#        'New Mexico', 'North Carolina', 'North Texas', 'Northern Illinois',
#        'Northwestern', 'Notre Dame', 'Ohio', 'Ohio State',
#        'Oklahoma State', 'Old Dominion', 'Ole Miss', 'Oregon',
#        'Oregon State', 'Penn State', 'Pittsburgh', 'Purdue', 'Rice',
#        'Rutgers', 'San Diego State', 'San Jose State', 'SMU',
#        'South Alabama', 'South Carolina', 'South Florida',
#        'Southern Miss', 'Stanford', 'TCU', 'Temple', 'Tennessee', 'Texas',
#        'Texas A&M', 'Texas State', 'Toledo', 'Troy', 'Tulane', 'Tulsa',
#        'UAB', 'UCF', 'UCLA', 'UL Monroe', 'UNLV', 'USC', 'Utah',
#        'Utah State', 'UTEP', 'UTSA', 'Virginia Tech', 'Wake Forest',
#        'Washington', 'West Virginia', 'Western Kentucky',
#        'Western Michigan', 'Wisconsin', 'Wyoming', 'BYU', 'California',
#        'Clemson', 'James Madison', 'New Mexico State', 'Oklahoma',
#        'Syracuse', 'Texas Tech', 'Uconn', 'Virginia', 'Washington State',
#        'Arkansas State', 'Jacksonville State', 'Massachusetts', 'Nevada',
#        'Vanderbilt', 'App State', 'Kennesaw State', 'Sam Houston'],
#       dtype=object)

# %%
team = st.selectbox('Select your team:', teams)
st.write(f'Selected team: {team{}')
