# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('2025 Teams.csv')
df
# Out:
#                       Team  code                 team_and_mascot
# 0               Ohio State   194             Ohio State Buckeyes
# 1                      LSU    99                      LSU Tigers
# 2                    Miami  2390                Miami Hurricanes
# 3            Florida State    52         Florida State Seminoles
# 4                   Auburn     2                   Auburn Tigers
# 5               Iowa State    66             Iowa State Cyclones
# 6             Georgia Tech    59     Georgia Tech Yellow Jackets
# 7           South Carolina  2579        South Carolina Gamecocks
# 8                 Nebraska   158            Nebraska Cornhuskers
# 9                Tennessee  2633            Tennessee Volunteers
# 10                    Utah   254                       Utah Utes
# 11           South Florida    58             South Florida Bulls
# 12                     TCU  2628                TCU Horned Frogs
# ...

# %%
df['Team'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Team'].value_counts()
# Out:
# Team
# Ohio State               1
# LSU                      1
# Miami                    1
# Florida State            1
# Auburn                   1
# Iowa State               1
# Georgia Tech             1
# South Carolina           1
# Nebraska                 1
# Tennessee                1
# Utah                     1
# South Florida            1
# TCU                      1
# Texas A&M                1
# Rice                     1
# Rutgers                  1
# Louisville               1
# Central Michigan         1
# NC State                 1
# California               1
# Kansas                   1
# Tulane                   1
# Maryland                 1
# Kentucky                 1
# Indiana                  1
# Wisconsin                1
# Mississippi State        1
# UCF                      1
# Oregon                   1
# Washington               1
# UNLV                     1
# Georgia                  1
# Wyoming                  1
# Minnesota                1
# ...

# %%
unique_team = df['Team'].unique()
unique_team = sorted(unique_team)
unique_team
# Out:
# ['Air Force',
#  'Akron',
#  'Alabama',
#  'App State',
#  'Arizona',
#  'Arizona State',
#  'Arkansas',
#  'Arkansas State',
#  'Army',
#  'Auburn',
#  'BYU',
#  'Ball State',
#  'Baylor',
#  'Boise State',
#  'Boston College',
#  'Bowling Green',
#  'Buffalo',
#  'California',
#  'Central Michigan',
#  'Charlotte',
#  'Cincinnati',
#  'Clemson',
#  'Coastal Carolina',
#  'Colorado',
#  'Colorado State',
#  'Delaware',
#  'Duke',
#  'East Carolina',
#  'Eastern Michigan',
#  'Florida',
#  'Florida Atlantic',
#  'Florida International',
#  'Florida State',
#  'Fresno State',
#  'Georgia',
#  'Georgia Southern',
#  'Georgia State',
#  'Georgia Tech',
#  "Hawai'i",
#  'Houston',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Iowa State',
#  'Jacksonville State',
#  'James Madison',
#  'Kansas',
#  'Kansas State',
#  'Kennesaw State',
#  'Kent State',
#  'Kentucky',
#  'LSU',
#  'Liberty',
#  'Louisiana',
#  'Louisiana Tech',
#  'Louisville',
#  'Marshall',
#  'Maryland',
# ...

# %%
df['Team'].value_counts().sort_index()
# Out:
# Team
# Air Force                1
# Akron                    1
# Alabama                  1
# App State                1
# Arizona                  1
# Arizona State            1
# Arkansas                 1
# Arkansas State           1
# Army                     1
# Auburn                   1
# BYU                      1
# Ball State               1
# Baylor                   1
# Boise State              1
# Boston College           1
# Bowling Green            1
# Buffalo                  1
# California               1
# Central Michigan         1
# Charlotte                1
# Cincinnati               1
# Clemson                  1
# Coastal Carolina         1
# Colorado                 1
# Colorado State           1
# Delaware                 1
# Duke                     1
# East Carolina            1
# Eastern Michigan         1
# Florida                  1
# Florida Atlantic         1
# Florida International    1
# Florida State            1
# Fresno State             1
# ...

# %%
df['code'].isna().sum()
# Out:
# np.int64(0)

# %%
df['code'].value_counts().sort_index()
# Out:
# code
# 2       1
# 5       1
# 6       1
# 8       1
# 9       1
# 12      1
# 21      1
# 23      1
# 24      1
# 25      1
# 26      1
# 30      1
# 36      1
# 38      1
# 41      1
# 48      1
# 52      1
# 55      1
# 57      1
# 58      1
# 59      1
# 61      1
# 62      1
# 66      1
# 68      1
# 77      1
# 84      1
# 87      1
# 96      1
# 97      1
# 98      1
# 99      1
# 103     1
# 113     1
# 120     1
# 127     1
# 130     1
# 135     1
# 142     1
# 145     1
# 150     1
# 151     1
# 153     1
# 154     2
# 158     1
# 164     1
# 166     1
# 167     1
# 183     1
# 189     1
# 193     1
# 194     1
# 195     1
# 197     1
# 201     1
# 202     1
# 204     1
# 213     1
# 218     1
# 221     1
# 228     1
# 235     1
# 238     1
# 239     1
# 242     1
# 245     1
# 248     1
# 249     1
# 251     1
# 252     1
# 254     1
# 256     1
# 258     1
# 259     1
# 264     1
# 265     1
# 275     1
# 276     1
# 277     1
# 278     1
# 290     1
# 295     1
# ...

# %%
df['code'].unique()
# Out:
# array([ 194,   99, 2390,   52,    2,   66,   59, 2579,  158, 2633,  254,
#          58, 2628,  245,  242,  164,   97, 2117,  154,   25, 2305, 2655,
#         120,   96,   84,  275,  344, 2116, 2483,  264, 2439,   61, 2751,
#         135,  130,  127,  145,  265,   98, 2026,  258,  248,  326,  213,
#          62,  218,  328,  197,   12,  278,    9, 2509,  235,  202,  201,
#        2032,   30,  142,  150, 2348, 2653, 2567, 2335, 2306, 2294,  189,
#         221, 2309,   21,  103,  356,    5,  238,   68,    6,  252,  256,
#         249,  277, 2459, 2433,   57,   41,    8, 2426, 2005,  166, 2229,
#          77,   48, 2641,   23,   24,   26,   36,   38,   55,   87,  113,
#         151,  153,  167,  183,  193,  195,  204,  228,  239,  251,  259,
#         276,  290,  295,  309,  324,  333,  338,  349, 2006, 2050, 2084,
#        2132, 2199, 2226, 2247, 2393, 2429, 2440, 2534, 2572, 2623, 2636,
#        2638, 2649, 2711])

# %%
df['team_and_mascot'].isna().sum()
# Out:
# np.int64(0)

# %%
df['team_and_mascot'].value_counts().sort_index()
# Out:
# team_and_mascot
# Air Force Falcons                 1
# Akron Zips                        1
# Alabama Crimson Tide              1
# App State Mountaineers            1
# Arizona State Sun Devils          1
# Arizona Wildcats                  1
# Arkansas Razorbacks               1
# Arkansas State Red Wolves         1
# Army Black Knights                1
# Auburn Tigers                     1
# BYU Cougars                       1
# Ball State Cardinals              1
# Baylor Bears                      1
# Boise State Broncos               1
# Boston College Eagles             1
# Bowling Green Falcons             1
# Buffalo Bulls                     1
# California Golden Bears           1
# Central Michigan Chippewas        1
# Charlotte 49ers                   1
# Cincinnati Bearcats               1
# Clemson Tigers                    1
# Coastal Carolina Chanticleers     1
# Colorado Buffaloes                1
# Colorado State Rams               1
# ...

# %%
unique_team_and_mascot = df['team_and_mascot'].unique()
unique_team_and_mascot = sorted(unique_team_and_mascot)
unique_team_and_mascot
# Out:
# ['Air Force Falcons',
#  'Akron Zips',
#  'Alabama Crimson Tide',
#  'App State Mountaineers',
#  'Arizona State Sun Devils',
#  'Arizona Wildcats',
#  'Arkansas Razorbacks',
#  'Arkansas State Red Wolves',
#  'Army Black Knights',
#  'Auburn Tigers',
#  'BYU Cougars',
#  'Ball State Cardinals',
#  'Baylor Bears',
#  'Boise State Broncos',
#  'Boston College Eagles',
#  'Bowling Green Falcons',
#  'Buffalo Bulls',
#  'California Golden Bears',
#  'Central Michigan Chippewas',
#  'Charlotte 49ers',
#  'Cincinnati Bearcats',
#  'Clemson Tigers',
#  'Coastal Carolina Chanticleers',
#  'Colorado Buffaloes',
#  'Colorado State Rams',
#  'Delaware Blue Hens',
#  'Duke Blue Devils',
#  'East Carolina Pirates',
#  'Eastern Michigan Eagles',
#  'Florida Atlantic Owls',
#  'Florida Gators',
#  'Florida International Panthers',
#  'Florida State Seminoles',
#  'Fresno State Bulldogs',
#  'Georgia Bulldogs',
#  'Georgia Southern Eagles',
#  'Georgia State Panthers',
# ...
