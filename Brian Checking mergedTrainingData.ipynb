# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
for i in df:
    print(i)
# Out:
# Unnamed: 0
# week
# season
# Team
# opponent
# code
# date
# win_loss
# OT
# OT_num
# pass
# rush
# rec
# points_allowed
# points_scored
# point_differential
# home_game
# CONF
# SOR
# FPI
# SOS
# GC
# AVGWP
# AP_rank
# opponent_rank
# rank_change

# %%
df = pd.read_csv('mergedTrainingData.csv')
# Out:
#       Unnamed: 0  week  season              Team          opponent  code  \
# 0              1    10    2021         Air Force              Army  2005
# 1              2    10    2021             Akron  Western Michigan  2006
# 2              3    10    2021           Alabama               LSU   333
# 3              4    10    2021           Arizona        California    12
# 4              5    10    2021     Arizona State               USC     9
# ...          ...   ...     ...               ...               ...   ...
# 5641        5642     9    2024     West Virginia           Arizona   277
# 5642        5643     9    2024  Western Kentucky    Kennesaw State    98
# 5643        5644     9    2024  Western Michigan        Kent State  2711
# 5644        5645     9    2024         Wisconsin        Penn State   275
# 5645        5646     9    2024           Wyoming        Utah State  2751
#
#              date win_loss     OT OT_num  ...  home_game           CONF  SOR  \
# 0      Sat, Nov 6        L   True         ...       True  Mountain West   33
# 1      Tue, Nov 9        L  False    NaN  ...      False            MAC  127
# 2      Sat, Nov 6        W  False    NaN  ...       True            SEC    2
# 3      Sat, Nov 6        W  False    NaN  ...       True         Pac-12  122
# 4      Sat, Nov 6        W  False    NaN  ...       True         Pac-12   49
# ...           ...      ...    ...    ...  ...        ...            ...  ...
# 5641  Sat, Oct 26        W  False    NaN  ...      False         Big 12   58
# 5642  Wed, Oct 30        W  False    NaN  ...       True           CUSA   84
# 5643  Sat, Oct 26        W  False    NaN  ...       True            MAC  103
# 5644  Sat, Oct 26        L  False    NaN  ...       True        Big Ten   55
# 5645  Sat, Oct 26        L  False    NaN  ...       True  Mountain West  119
#
#       FPI  SOS   GC  AVGWP AP_rank  opponent_rank  rank_change
# 0      66  110   24      6     NaN            NaN          0.0
# 1     128   67  118    125     NaN            NaN          0.0
# 2       2    1    2      3     3.0            NaN         -1.0
# 3     106   71  110    122     NaN            NaN          0.0
# 4      39   61   61     63     NaN            NaN          0.0
# ...   ...  ...  ...    ...     ...            ...          ...
# 5641   63   54   64     81     NaN            NaN          0.0
# 5642   99   80   77     56     NaN            NaN          0.0
# 5643  108   70  103     87     NaN            NaN          0.0
# 5644   47   32   41     76     NaN            3.0          0.0
# 5645  113   97  124    125     NaN            NaN          0.0
#
# [5646 rows x 26 columns]

# %%
df['week'].isna().sum()
# Out:
# np.int64(0)

# %%
unique_week = df['week'].unique()
unique_week = sorted(unique_week)
unique_week
# Out:
# [np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(18)]

# %%
df['week'].value_counts().sort_index()
# Out:
# week
# 2     362
# 3     407
# 4     447
# 5     458
# 6     428
# 7     423
# 8     440
# 9     443
# 10    464
# 11    465
# 12    477
# 13    462
# 14    282
# 15     68
# 16     13
# 17      3
# 18      4
# Name: count, dtype: int64

# %%
df['week'].unique()
# Out:
# array([10, 11, 12, 13, 14, 15, 16, 17, 18,  2,  3,  4,  5,  6,  7,  8,  9])

# %%
df['season'].isna().sum()
# Out:
# np.int64(0)

# %%
df['season'].value_counts().sort_index()
# Out:
# season
# 2021    1379
# 2022    1391
# 2023    1412
# 2024    1464
# Name: count, dtype: int64

# %%
df['season'].unique()
# Out:
# array([2021, 2022, 2023, 2024])

# %%
unique_season = df['season'].unique()
unique_season = sorted(unique_season)
unique_season
# Out:
# [np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]

# %%
df['Team'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Team'].unique()
# Out:
# array(['Air Force', 'Akron', 'Alabama', 'Arizona', 'Arizona State',
#        'Arkansas', 'Army', 'Auburn', 'Ball State', 'Baylor',
#        'Boise State', 'Boston College', 'Bowling Green', 'Buffalo',
#        'Central Michigan', 'Charlotte', 'Cincinnati', 'Coastal Carolina',
#        'Colorado', 'Colorado State', 'Duke', 'East Carolina',
#        'Eastern Michigan', 'Florida', 'Florida Atlantic',
#        'Florida International', 'Florida State', 'Fresno State',
#        'Georgia', 'Georgia Southern', 'Georgia State', 'Georgia Tech',
#        "Hawai'i", 'Houston', 'Illinois', 'Indiana', 'Iowa', 'Iowa State',
#        'Kansas', 'Kansas State', 'Kent State', 'Kentucky', 'Liberty',
#        'Louisiana', 'Louisiana Tech', 'Louisville', 'LSU', 'Marshall',
#        'Maryland', 'Memphis', 'Miami', 'Miami (OH)', 'Michigan',
#        'Michigan State', 'Middle Tennessee', 'Minnesota',
#        'Mississippi State', 'Missouri', 'Navy', 'NC State', 'Nebraska',
#        'New Mexico', 'North Carolina', 'North Texas', 'Northern Illinois',
#        'Northwestern', 'Notre Dame', 'Ohio', 'Ohio State',
#        'Oklahoma State', 'Old Dominion', 'Ole Miss', 'Oregon',
#        'Oregon State', 'Penn State', 'Pittsburgh', 'Purdue', 'Rice',
#        'Rutgers', 'San Diego State', 'San Jose State', 'SMU',
#        'South Alabama', 'South Carolina', 'South Florida',
#        'Southern Miss', 'Stanford', 'TCU', 'Temple', 'Tennessee', 'Texas',
#        'Texas A&M', 'Texas State', 'Toledo', 'Troy', 'Tulane', 'Tulsa',
#        'UAB', 'UCF', 'UCLA', 'UL Monroe', 'UNLV', 'USC', 'Utah',
#        'Utah State', 'UTEP', 'UTSA', 'Virginia Tech', 'Wake Forest',
#        'Washington', 'West Virginia', 'Western Kentucky',
#        'Western Michigan', 'Wisconsin', 'Wyoming', 'BYU', 'California',
#        'Clemson', 'James Madison', 'New Mexico State', 'Oklahoma',
#        'Syracuse', 'Texas Tech', 'Uconn', 'Virginia', 'Washington State',
#        'Arkansas State', 'Jacksonville State', 'Massachusetts', 'Nevada',
#        'Vanderbilt', 'App State', 'Kennesaw State', 'Sam Houston'],
#       dtype=object)

# %%
unique_team = df['Team'].unique()
unique_team = sorted(unique_team)
unique_team
# Out:
# ['Air Force',
#  'Akron',
#  'Alabama',
#  'App State',
#  'Arizona',
#  'Arizona State',
#  'Arkansas',
#  'Arkansas State',
#  'Army',
#  'Auburn',
#  'BYU',
#  'Ball State',
#  'Baylor',
#  'Boise State',
#  'Boston College',
#  'Bowling Green',
#  'Buffalo',
#  'California',
#  'Central Michigan',
#  'Charlotte',
#  'Cincinnati',
#  'Clemson',
#  'Coastal Carolina',
#  'Colorado',
#  'Colorado State',
#  'Duke',
#  'East Carolina',
#  'Eastern Michigan',
#  'Florida',
#  'Florida Atlantic',
#  'Florida International',
#  'Florida State',
#  'Fresno State',
#  'Georgia',
#  'Georgia Southern',
#  'Georgia State',
#  'Georgia Tech',
#  "Hawai'i",
#  'Houston',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Iowa State',
#  'Jacksonville State',
#  'James Madison',
#  'Kansas',
#  'Kansas State',
#  'Kennesaw State',
#  'Kent State',
#  'Kentucky',
#  'LSU',
#  'Liberty',
#  'Louisiana',
#  'Louisiana Tech',
#  'Louisville',
#  'Marshall',
#  'Maryland',
#  'Massachusetts',
#  'Memphis',
#  'Miami',
#  'Miami (OH)',
#  'Michigan',
#  'Michigan State',
#  'Middle Tennessee',
#  'Minnesota',
#  'Mississippi State',
#  'Missouri',
#  'NC State',
#  'Navy',
#  'Nebraska',
#  'Nevada',
#  'New Mexico',
#  'New Mexico State',
#  'North Carolina',
#  'North Texas',
#  'Northern Illinois',
#  'Northwestern',
#  'Notre Dame',
#  'Ohio',
#  'Ohio State',
#  'Oklahoma',
#  'Oklahoma State',
#  'Old Dominion',
#  'Ole Miss',
#  'Oregon',
#  'Oregon State',
#  'Penn State',
#  'Pittsburgh',
#  'Purdue',
#  'Rice',
#  'Rutgers',
#  'SMU',
#  'Sam Houston',
#  'San Diego State',
#  'San Jose State',
#  'South Alabama',
#  'South Carolina',
#  'South Florida',
#  'Southern Miss',
#  'Stanford',
#  'Syracuse',
#  'TCU',
#  'Temple',
#  'Tennessee',
#  'Texas',
#  'Texas A&M',
#  'Texas State',
#  'Texas Tech',
#  'Toledo',
#  'Troy',
#  'Tulane',
#  'Tulsa',
#  'UAB',
#  'UCF',
#  'UCLA',
#  'UL Monroe',
#  'UNLV',
#  'USC',
#  'UTEP',
#  'UTSA',
#  'Uconn',
#  'Utah',
#  'Utah State',
#  'Vanderbilt',
#  'Virginia',
#  'Virginia Tech',
#  'Wake Forest',
#  'Washington',
#  'Washington State',
#  'West Virginia',
#  'Western Kentucky',
#  'Western Michigan',
#  'Wisconsin',
#  'Wyoming']

# %%
df['Team'].value_counts().sort_index()
# Out:
# Team
# Air Force                44
# Akron                    41
# Alabama                  47
# App State                10
# Arizona                  42
# Arizona State            46
# Arkansas                 45
# Arkansas State           42
# Army                     36
# Auburn                   43
# BYU                      42
# Ball State               42
# Baylor                   45
# Boise State              44
# Boston College           41
# Bowling Green            44
# Buffalo                  43
# California               43
# Central Michigan         42
# Charlotte                41
# Cincinnati               45
# Clemson                  44
# Coastal Carolina         39
# Colorado                 44
# Colorado State           39
# Duke                     42
# East Carolina            40
# Eastern Michigan         45
# Florida                  41
# Florida Atlantic         40
# Florida International    40
# Florida State            44
# Fresno State             39
# Georgia                  49
# Georgia Southern         42
# Georgia State            38
# Georgia Tech             42
# Hawai'i                  39
# Houston                  42
# Illinois                 44
# Indiana                  41
# Iowa                     48
# Iowa State               45
# Jacksonville State       23
# James Madison            29
# Kansas                   46
# Kansas State             47
# Kennesaw State            9
# Kent State               42
# Kentucky                 43
# LSU                      45
# Liberty                  44
# Louisiana                47
# Louisiana Tech           42
# Louisville               45
# Marshall                 42
# Maryland                 45
# Massachusetts            34
# Memphis                  46
# Miami                    41
# Miami (OH)               45
# Michigan                 51
# Michigan State           42
# Middle Tennessee         43
# Minnesota                44
# Mississippi State        44
# Missouri                 46
# NC State                 44
# Navy                     42
# Nebraska                 41
# Nevada                   38
# New Mexico               41
# New Mexico State         40
# North Carolina           38
# North Texas              43
# Northern Illinois        45
# Northwestern             41
# Notre Dame               48
# Ohio                     43
# Ohio State               49
# Oklahoma                 45
# Oklahoma State           46
# Old Dominion             39
# Ole Miss                 45
# Oregon                   48
# Oregon State             43
# Penn State               47
# Pittsburgh               43
# Purdue                   45
# Rice                     40
# Rutgers                  44
# SMU                      45
# Sam Houston              22
# San Diego State          41
# San Jose State           41
# South Alabama            43
# South Carolina           44
# South Florida            40
# Southern Miss            40
# Stanford                 41
# Syracuse                 42
# TCU                      45
# Temple                   40
# Tennessee                44
# Texas                    49
# Texas A&M                42
# Texas State              41
# Texas Tech               46
# Toledo                   48
# Troy                     41
# Tulane                   46
# Tulsa                    44
# UAB                      44
# UCF                      42
# UCLA                     43
# UL Monroe                39
# UNLV                     41
# USC                      47
# UTEP                     41
# UTSA                     47
# Uconn                    40
# Utah                     46
# Utah State               39
# Vanderbilt               41
# Virginia                 42
# Virginia Tech            44
# Wake Forest              44
# Washington               48
# Washington State         41
# West Virginia            42
# Western Kentucky         47
# Western Michigan         41
# Wisconsin                46
# Wyoming                  38
# Name: count, dtype: int64

# %%
df['opponent'].isna().sum()
# Out:
# np.int64(0)

# %%
df['opponent'].value_counts().sort_index()
# Out:
# opponent
# Air Force                47
# Akron                    40
# Alabama                  47
# App State                10
# Arizona                  42
# Arizona State            46
# Arkansas                 45
# Arkansas State           44
# Army                     43
# Auburn                   44
# BYU                      44
# Ball State               41
# Baylor                   45
# Boise State              46
# Boston College           43
# Bowling Green            41
# Buffalo                  44
# California               40
# Central Michigan         41
# Charlotte                40
# Cincinnati               45
# Clemson                  45
# Coastal Carolina         40
# Colorado                 45
# Colorado State           39
# Duke                     43
# East Carolina            39
# Eastern Michigan         44
# Florida                  43
# Florida Atlantic         40
# Florida International    42
# Florida State            42
# Fresno State             43
# Georgia                  51
# Georgia Southern         43
# Georgia State            43
# Georgia Tech             39
# Hawai'i                  41
# Houston                  44
# Illinois                 43
# Indiana                  42
# Iowa                     50
# Iowa State               48
# Jacksonville State       24
# James Madison            30
# Kansas                   45
# Kansas State             47
# Kennesaw State           10
# Kent State               42
# Kentucky                 42
# LSU                      47
# Liberty                  47
# Louisiana                46
# Louisiana Tech           38
# Louisville               46
# Marshall                 41
# Maryland                 43
# Massachusetts            36
# Memphis                  43
# Miami                    40
# Miami (OH)               44
# Michigan                 52
# Michigan State           41
# Middle Tennessee         44
# Minnesota                47
# Mississippi State        43
# Missouri                 46
# NC State                 46
# Navy                     42
# Nebraska                 42
# Nevada                   41
# New Mexico               42
# New Mexico State         42
# North Carolina           43
# North Texas              44
# Northern Illinois        43
# Northwestern             40
# Notre Dame               49
# Ohio                     45
# Ohio State               48
# Oklahoma                 47
# Oklahoma State           47
# Old Dominion             43
# Ole Miss                 46
# Oregon                   48
# Oregon State             42
# Penn State               49
# Pittsburgh               48
# Purdue                   46
# Rice                     41
# Rutgers                  43
# SMU                      47
# Sam Houston              21
# San Diego State          45
# South Alabama            42
# South Carolina           44
# South Florida            42
# Southern Miss            40
# Stanford                 41
# Syracuse                 41
# TCU                      44
# Temple                   40
# Tennessee                42
# Texas                    51
# Texas A&M                42
# Texas State              42
# Texas Tech               44
# Toledo                   49
# Troy                     42
# Tulane                   47
# Tulsa                    43
# UAB                      46
# UCF                      46
# UCLA                     43
# UL Monroe                39
# UNLV                     47
# USC                      47
# UTEP                     41
# UTSA                     47
# Utah                     46
# Utah State               44
# Vanderbilt               44
# Virginia                 40
# Virginia Tech            40
# Wake Forest              42
# Washington               46
# Washington State         44
# West Virginia            41
# Western Kentucky         47
# Western Michigan         42
# Wisconsin                46
# Wyoming                  41
# Name: count, dtype: int64

# %%
unique_opponent = df['opponent'].unique()
unique_opponent = sorted(unique_opponent)
unique_opponent
# Out:
# ['Air Force',
#  'Akron',
#  'Alabama',
#  'App State',
#  'Arizona',
#  'Arizona State',
#  'Arkansas',
#  'Arkansas State',
#  'Army',
#  'Auburn',
#  'BYU',
#  'Ball State',
#  'Baylor',
#  'Boise State',
#  'Boston College',
#  'Bowling Green',
#  'Buffalo',
#  'California',
#  'Central Michigan',
#  'Charlotte',
#  'Cincinnati',
#  'Clemson',
#  'Coastal Carolina',
#  'Colorado',
#  'Colorado State',
#  'Duke',
#  'East Carolina',
#  'Eastern Michigan',
#  'Florida',
#  'Florida Atlantic',
#  'Florida International',
#  'Florida State',
#  'Fresno State',
#  'Georgia',
#  'Georgia Southern',
#  'Georgia State',
#  'Georgia Tech',
#  "Hawai'i",
#  'Houston',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Iowa State',
#  'Jacksonville State',
#  'James Madison',
#  'Kansas',
#  'Kansas State',
#  'Kennesaw State',
#  'Kent State',
#  'Kentucky',
#  'LSU',
#  'Liberty',
#  'Louisiana',
#  'Louisiana Tech',
#  'Louisville',
#  'Marshall',
#  'Maryland',
#  'Massachusetts',
#  'Memphis',
#  'Miami',
#  'Miami (OH)',
#  'Michigan',
#  'Michigan State',
#  'Middle Tennessee',
#  'Minnesota',
#  'Mississippi State',
#  'Missouri',
#  'NC State',
#  'Navy',
#  'Nebraska',
#  'Nevada',
#  'New Mexico',
#  'New Mexico State',
#  'North Carolina',
#  'North Texas',
#  'Northern Illinois',
#  'Northwestern',
#  'Notre Dame',
#  'Ohio',
#  'Ohio State',
#  'Oklahoma',
#  'Oklahoma State',
#  'Old Dominion',
#  'Ole Miss',
#  'Oregon',
#  'Oregon State',
#  'Penn State',
#  'Pittsburgh',
#  'Purdue',
#  'Rice',
#  'Rutgers',
#  'SMU',
#  'Sam Houston',
#  'San Diego State',
#  'South Alabama',
#  'South Carolina',
#  'South Florida',
#  'Southern Miss',
#  'Stanford',
#  'Syracuse',
#  'TCU',
#  'Temple',
#  'Tennessee',
#  'Texas',
#  'Texas A&M',
#  'Texas State',
#  'Texas Tech',
#  'Toledo',
#  'Troy',
#  'Tulane',
#  'Tulsa',
#  'UAB',
#  'UCF',
#  'UCLA',
#  'UL Monroe',
#  'UNLV',
#  'USC',
#  'UTEP',
#  'UTSA',
#  'Utah',
#  'Utah State',
#  'Vanderbilt',
#  'Virginia',
#  'Virginia Tech',
#  'Wake Forest',
#  'Washington',
#  'Washington State',
#  'West Virginia',
#  'Western Kentucky',
#  'Western Michigan',
#  'Wisconsin',
#  'Wyoming']

# %%
df['opponent'].unique()
# Out:
# array(['Army', 'Western Michigan', 'LSU', 'California', 'USC',
#        'Mississippi State', 'Air Force', 'Texas A&M', 'Northern Illinois',
#        'TCU', 'Fresno State', 'Virginia Tech', 'Toledo', 'Miami (OH)',
#        'Kent State', 'Louisiana Tech', 'Tulsa', 'Georgia State',
#        'Oregon State', 'Wyoming', 'Pittsburgh', 'Temple', 'Ohio',
#        'South Carolina', 'Old Dominion', 'NC State', 'San Diego State',
#        'Missouri', 'Coastal Carolina', 'Louisiana', 'Miami', 'Utah State',
#        'South Florida', 'Rutgers', 'Michigan', 'Northwestern', 'Texas',
#        'Kansas State', 'Kansas', 'Central Michigan', 'Tennessee',
#        'Ole Miss', 'Troy', 'UAB', 'Clemson', 'Alabama',
#        'Florida Atlantic', 'Penn State', 'SMU', 'Georgia Tech', 'Buffalo',
#        'Indiana', 'Purdue', 'Florida International', 'Illinois',
#        'Arkansas', 'Georgia', 'Notre Dame', 'North Carolina', 'UNLV',
#        'Wake Forest', 'Southern Miss', 'Ball State', 'Iowa', 'Navy',
#        'Eastern Michigan', 'Nebraska', 'West Virginia', 'Liberty',
#        'Washington State', 'Colorado', 'Maryland', 'Duke',
#        'Michigan State', 'Charlotte', 'Wisconsin', "Hawai'i", 'UCF',
#        'Florida', 'Houston', 'North Texas', 'Utah', 'Baylor',
#        'East Carolina', 'Kentucky', 'Iowa State', 'Auburn', 'UL Monroe',
#        'Bowling Green', 'Tulane', 'Texas State', 'New Mexico',
#        'Arizona State', 'Stanford', 'New Mexico State', 'UTEP',
#        'Boston College', 'Oregon', 'Oklahoma State', 'Middle Tennessee',
#        'Akron', 'Colorado State', 'UCLA', 'BYU', 'Boise State', 'Rice',
#        'South Alabama', 'Louisville', 'Georgia Southern', 'James Madison',
#        'Florida State', 'Cincinnati', 'Massachusetts', 'Western Kentucky',
#        'Marshall', 'Syracuse', 'Vanderbilt', 'Texas Tech', 'Memphis',
#        'UTSA', 'Oklahoma', 'Virginia', 'Minnesota', 'Arkansas State',
#        'Ohio State', 'Jacksonville State', 'Arizona', 'Nevada',
#        'App State', 'Washington', 'Kennesaw State', 'Sam Houston'],
#       dtype=object)

# %%
df['code'].isna().sum()
# Out:
# np.int64(0)

# %%
df['code'].unique()
# Out:
# array([2005, 2006,  333,   12,    9,    8,  349,    2, 2050,  239,   68,
#         103,  189, 2084, 2117, 2429, 2132,  324,   38,   36,  150,  151,
#        2199,   57, 2226, 2229,   52,  278,   61,  290, 2247,   59,   62,
#         248,  356,   84, 2294,   66, 2305, 2306, 2309,   96, 2335,  309,
#        2348,   97,   99,  276,  120,  235, 2390,  193,  130,  127, 2393,
#         135,  344,  142, 2426,  154,  158,  167,  153,  249, 2459,   77,
#          87,  195,  194,  197,  295,  145, 2483,  204,  213,  221, 2509,
#         242,  164,   21,   23, 2567,    6, 2579,   58, 2572,   24, 2628,
#         218, 2633,  251,  245,  326, 2649, 2653, 2655,  202,    5, 2116,
#          26, 2433, 2439,   30,  254,  328, 2638, 2636,  259,  264,  277,
#          98, 2711,  275, 2751,  252,   25,  228,  256,  166,  201,  183,
#        2641,   41,  258,  265, 2032,   55,  113, 2440,  238, 2026,  338,
#        2534])

# %%
df['code'].value_counts().sort_index()
# Out:
# code
# 2       43
# 5       44
# 6       43
# 8       45
# 9       46
# 12      42
# 21      41
# 23      41
# 24      41
# 25      43
# 26      43
# 30      47
# 36      39
# 38      44
# 41      40
# 52      44
# 55      23
# 57      41
# 58      40
# 59      42
# 61      49
# 62      39
# 66      45
# 68      44
# 77      41
# 84      41
# 87      48
# 96      43
# 97      45
# 98      47
# 99      45
# 103     41
# 113     34
# 120     45
# 127     42
# 130     51
# 135     44
# 142     46
# 145     45
# 150     42
# 151     40
# 153     38
# 154     88
# 158     41
# 164     44
# 166     40
# 167     41
# 183     42
# 189     44
# 193     45
# 194     49
# 195     43
# 197     46
# 201     45
# 202     44
# 204     43
# 213     47
# 218     40
# 221     43
# 228     44
# 235     46
# 238     41
# 239     45
# 242     40
# 245     42
# 248     42
# 249     43
# 251     49
# 252     42
# 254     46
# 256     29
# 258     42
# 259     44
# 264     48
# 265     41
# 275     46
# 276     42
# 277     42
# 278     39
# 290     42
# 295     39
# 309     47
# 324     39
# 326     41
# 328     39
# 333     47
# 338      9
# 344     44
# 349     36
# 356     44
# 2005    44
# 2006    41
# 2026    10
# 2032    42
# 2050    42
# 2084    43
# 2116    42
# 2117    42
# 2132    45
# 2199    45
# 2226    40
# 2229    40
# 2247    38
# 2294    48
# 2305    46
# 2306    47
# 2309    42
# 2335    44
# 2348    42
# 2390    41
# 2393    43
# 2426    42
# 2429    41
# 2433    39
# 2439    41
# 2440    38
# 2459    45
# 2483    48
# 2509    45
# 2534    22
# 2567    45
# 2572    40
# 2579    44
# 2628    45
# 2633    44
# 2636    47
# 2638    41
# 2641    46
# 2649    48
# 2653    41
# 2655    46
# 2711    41
# 2751    38
# Name: count, dtype: int64

# %%
df['date'].isna().sum()
# Out:
# np.int64(0)

# %%
df['date'].unique()
# Out:
# array(['Sat, Nov 6', 'Tue, Nov 9', 'Wed, Nov 10', 'Fri, Nov 5',
#        'Sat, Nov 13', 'Sat, Oct 30', 'Thu, Nov 4', 'Sat, Nov 5',
#        'Tue, Nov 8', 'Sat, Nov 12', 'Fri, Nov 4', 'Wed, Nov 9',
#        'Sat, Oct 29', 'Thu, Nov 10', 'Thu, Nov 3', 'Sat, Nov 4',
#        'Wed, Nov 8', 'Tue, Nov 7', 'Fri, Nov 3', 'Sat, Nov 11',
#        'Thu, Nov 2', 'Wed, Oct 25', 'Tue, Oct 24', 'Sat, Oct 28',
#        'Fri, Nov 10', 'Thu, Nov 9', 'Sat, Nov 2', 'Tue, Nov 12',
#        'Sat, Nov 9', 'Tue, Nov 5', 'Fri, Nov 8', 'Thu, Oct 31',
#        'Thu, Nov 7', 'Sat, Oct 26', 'Wed, Nov 6', 'Fri, Nov 1',
#        'Sat, Nov 16', 'Sat, Nov 20', 'Wed, Nov 17', 'Fri, Nov 12',
#        'Tue, Nov 16', 'Thu, Nov 11', 'Tue, Nov 15', 'Sat, Nov 19',
#        'Wed, Nov 16', 'Fri, Nov 11', 'Thu, Nov 17', 'Fri, Nov 18',
#        'Tue, Nov 14', 'Sat, Nov 18', 'Wed, Nov 15', 'Wed, Nov 13',
#        'Fri, Nov 15', 'Sat, Nov 23', 'Thu, Nov 14', 'Fri, Nov 19',
#        'Sat, Nov 27', 'Tue, Nov 23', 'Fri, Nov 26', 'Thu, Nov 18',
#        'Sat, Nov 26', 'Tue, Nov 22', 'Fri, Nov 25', 'Fri, Nov 24',
#        'Sat, Nov 25', 'Thu, Nov 16', 'Tue, Nov 21', 'Fri, Nov 17',
#        'Tue, Nov 19', 'Fri, Nov 29', 'Wed, Nov 20', 'Sat, Nov 30',
#        'Fri, Nov 22', 'Sat, Dec 25', 'Sat, Dec 4', 'Fri, Dec 31',
#        'Wed, Dec 29', 'Fri, Dec 17', 'Sat, Dec 18', 'Thu, Dec 23',
#        'Thu, Nov 25', 'Fri, Dec 3', 'Mon, Dec 20', 'Mon, Dec 27',
#        'Fri, Dec 2', 'Thu, Dec 22', 'Mon, Dec 26', 'Wed, Dec 28',
#        'Fri, Dec 23', 'Fri, Dec 16', 'Thu, Nov 24', 'Sat, Dec 10',
#        'Sat, Dec 3', 'Sat, Dec 17', 'Thu, Dec 29', 'Sat, Dec 9',
#        'Tue, Dec 26', 'Sat, Dec 23', 'Thu, Dec 28', 'Fri, Dec 1',
#        'Fri, Dec 29', 'Sat, Dec 2', 'Thu, Nov 23', 'Thu, Dec 21',
#        'Sat, Dec 16', 'Wed, Dec 27', 'Mon, Dec 18', 'Tue, Nov 26',
#        'Thu, Nov 21', 'Thu, Nov 28', 'Fri, Dec 27', 'Tue, Dec 28',
#        'Thu, Dec 30', 'Sat, Jan 1', 'Sat, Dec 11', 'Tue, Jan 4',
#        'Tue, Dec 21', 'Wed, Dec 22', 'Sat, Dec 31', 'Tue, Dec 27',
#        'Mon, Jan 2', 'Tue, Dec 20', 'Fri, Dec 30', 'Sat, Dec 24',
#        'Wed, Dec 21', 'Sat, Dec 30', 'Fri, Dec 22', 'Mon, Jan 1',
#        'Tue, Dec 19', 'Fri, Dec 6', 'Sat, Dec 28', 'Thu, Dec 26',
#        'Sat, Jan 4', 'Wed, Dec 18', 'Thu, Jan 2', 'Sat, Dec 7',
#        'Tue, Dec 17', 'Sat, Dec 14', 'Mon, Dec 23', 'Thu, Dec 19',
#        'Fri, Jan 3', 'Tue, Dec 31', 'Fri, Dec 20', 'Mon, Dec 30',
#        'Sat, Dec 21', 'Wed, Jan 1', 'Mon, Jan 10', 'Mon, Jan 9',
#        'Mon, Jan 8', 'Thu, Jan 9', 'Fri, Jan 10', 'Mon, Jan 20',
#        'Sat, Sep 11', 'Fri, Sep 10', 'Sat, Sep 4', 'Sat, Sep 10',
#        'Fri, Sep 9', 'Sat, Sep 3', 'Sun, Sep 4', 'Fri, Sep 2',
#        'Thu, Sep 1', 'Sat, Sep 9', 'Fri, Sep 1', 'Fri, Sep 8',
#        'Sat, Sep 2', 'Sun, Sep 3', 'Sat, Sep 7', 'Sat, Sep 14',
#        'Fri, Sep 6', 'Mon, Sep 2', 'Sat, Aug 31', 'Sat, Sep 18',
#        'Thu, Sep 16', 'Fri, Sep 17', 'Fri, Sep 16', 'Sat, Sep 17',
#        'Fri, Sep 15', 'Sat, Sep 16', 'Thu, Sep 14', 'Fri, Sep 13',
#        'Thu, Sep 12', 'Sat, Sep 21', 'Fri, Sep 20', 'Sat, Sep 25',
#        'Fri, Sep 24', 'Sun, Sep 19', 'Fri, Sep 23', 'Sat, Sep 24',
#        'Thu, Sep 22', 'Sat, Sep 23', 'Fri, Sep 22', 'Thu, Sep 21',
#        'Thu, Sep 19', 'Sat, Sep 28', 'Sat, Oct 2', 'Fri, Oct 1',
#        'Thu, Sep 30', 'Sat, Oct 1', 'Fri, Sep 30', 'Thu, Sep 29',
#        'Fri, Oct 7', 'Wed, Oct 5', 'Sat, Sep 30', 'Fri, Sep 29',
#        'Fri, Oct 6', 'Thu, Oct 5', 'Thu, Sep 28', 'Thu, Sep 26',
#        'Sat, Oct 5', 'Fri, Oct 4', 'Fri, Sep 27', 'Thu, Oct 3',
#        'Sat, Oct 9', 'Fri, Oct 8', 'Thu, Oct 7', 'Fri, Oct 15',
#        'Sat, Oct 8', 'Thu, Oct 13', 'Sat, Oct 15', 'Wed, Oct 12',
#        'Fri, Oct 14', 'Sat, Oct 7', 'Thu, Oct 12', 'Wed, Oct 4',
#        'Sat, Oct 14', 'Tue, Oct 10', 'Fri, Oct 13', 'Sat, Oct 12',
#        'Tue, Oct 8', 'Wed, Oct 9', 'Thu, Oct 10', 'Fri, Oct 11',
#        'Sat, Oct 16', 'Sat, Oct 23', 'Thu, Oct 21', 'Thu, Oct 14',
#        'Sat, Oct 22', 'Thu, Oct 20', 'Fri, Oct 21', 'Sat, Oct 21',
#        'Wed, Oct 11', 'Tue, Oct 17', 'Thu, Oct 19', 'Fri, Oct 20',
#        'Sat, Oct 19', 'Thu, Oct 17', 'Fri, Oct 18', 'Wed, Oct 16',
#        'Tue, Oct 15', 'Thu, Oct 24', 'Fri, Oct 22', 'Thu, Oct 28',
#        'Fri, Oct 29', 'Thu, Oct 27', 'Wed, Oct 18', 'Thu, Oct 26',
#        'Fri, Oct 25', 'Tue, Oct 22', 'Wed, Oct 23', 'Tue, Nov 2',
#        'Wed, Nov 3', 'Tue, Nov 1', 'Wed, Nov 2', 'Fri, Oct 28',
#        'Wed, Nov 1', 'Tue, Oct 31', 'Fri, Oct 27', 'Tue, Oct 29',
#        'Wed, Oct 30'], dtype=object)

# %%
df['date'].value_counts().sort_index()
# Out:
# date
# Fri, Dec 1       4
# Fri, Dec 16      3
# Fri, Dec 17      3
# Fri, Dec 2       6
# Fri, Dec 20      6
# Fri, Dec 22      2
# Fri, Dec 23      4
# Fri, Dec 27      9
# Fri, Dec 29      6
# Fri, Dec 3       4
# Fri, Dec 30      7
# Fri, Dec 31      6
# Fri, Dec 6       6
# Fri, Jan 10      2
# Fri, Jan 3       2
# Fri, Nov 1       5
# Fri, Nov 10      4
# Fri, Nov 11      6
# Fri, Nov 12      4
# Fri, Nov 15      8
# Fri, Nov 17      4
# Fri, Nov 18      4
# Fri, Nov 19     10
# Fri, Nov 22      5
# Fri, Nov 24     24
# Fri, Nov 25     24
# Fri, Nov 26     31
# Fri, Nov 29     23
# Fri, Nov 3       4
# Fri, Nov 4       5
# Fri, Nov 5       4
# Fri, Nov 8       9
# Fri, Oct 1       6
# Fri, Oct 11      6
# Fri, Oct 13      6
# Fri, Oct 14      4
# Fri, Oct 15      7
# Fri, Oct 18      8
# Fri, Oct 20      2
# Fri, Oct 21      4
# Fri, Oct 22      7
# Fri, Oct 25      6
# Fri, Oct 27      2
# Fri, Oct 28      4
# Fri, Oct 29      4
# Fri, Oct 4       8
# Fri, Oct 6       4
# Fri, Oct 7       7
# Fri, Oct 8       6
# Fri, Sep 1       1
# Fri, Sep 10      4
# Fri, Sep 13      4
# Fri, Sep 15      6
# Fri, Sep 16      4
# Fri, Sep 17      4
# Fri, Sep 2       1
# Fri, Sep 20      5
# Fri, Sep 22      6
# Fri, Sep 23      6
# Fri, Sep 24      9
# Fri, Sep 27      4
# Fri, Sep 29      7
# Fri, Sep 30     10
# Fri, Sep 6       4
# Fri, Sep 8       2
# Fri, Sep 9       4
# Mon, Dec 18      1
# Mon, Dec 20      1
# Mon, Dec 23      2
# Mon, Dec 26      1
# Mon, Dec 27      1
# Mon, Dec 30      2
# Mon, Jan 1       8
# Mon, Jan 10      2
# Mon, Jan 2       8
# Mon, Jan 20      2
# Mon, Jan 8       2
# Mon, Jan 9       2
# Mon, Sep 2       1
# Sat, Aug 31      4
# Sat, Dec 10      1
# Sat, Dec 11      2
# Sat, Dec 14      3
# Sat, Dec 16      6
# Sat, Dec 17      9
# Sat, Dec 18      7
# Sat, Dec 2      14
# Sat, Dec 21      6
# Sat, Dec 23     10
# Sat, Dec 24      2
# Sat, Dec 25      1
# Sat, Dec 28      9
# Sat, Dec 3      16
# Sat, Dec 30      8
# Sat, Dec 31      6
# Sat, Dec 4      16
# Sat, Dec 7      12
# Sat, Dec 9       1
# Sat, Jan 1       6
# Sat, Jan 4       2
# Sat, Nov 11    104
# Sat, Nov 12    102
# Sat, Nov 13     98
# Sat, Nov 16     84
# Sat, Nov 18    108
# Sat, Nov 19    100
# Sat, Nov 2      77
# Sat, Nov 20     99
# Sat, Nov 23    106
# Sat, Nov 25     90
# Sat, Nov 26     88
# Sat, Nov 27     83
# Sat, Nov 30     90
# Sat, Nov 4     102
# Sat, Nov 5     100
# Sat, Nov 6      99
# Sat, Nov 9      77
# Sat, Oct 1     100
# Sat, Oct 12     87
# Sat, Oct 14     89
# Sat, Oct 15     89
# Sat, Oct 16     87
# Sat, Oct 19     93
# Sat, Oct 2     110
# Sat, Oct 21     89
# Sat, Oct 22     95
# Sat, Oct 23     88
# Sat, Oct 26     93
# Sat, Oct 28     90
# Sat, Oct 29     83
# Sat, Oct 30     95
# Sat, Oct 5      84
# Sat, Oct 7      84
# Sat, Oct 8     101
# Sat, Oct 9      91
# Sat, Sep 10     87
# Sat, Sep 11     82
# Sat, Sep 14     96
# Sat, Sep 16     97
# Sat, Sep 17     93
# Sat, Sep 18     96
# Sat, Sep 2       3
# Sat, Sep 21     98
# Sat, Sep 23    114
# Sat, Sep 24    107
# Sat, Sep 25    103
# Sat, Sep 28     97
# Sat, Sep 3       8
# Sat, Sep 30     95
# Sat, Sep 4       5
# Sat, Sep 7      93
# Sat, Sep 9      89
# Sun, Sep 19      1
# Sun, Sep 3       1
# Sun, Sep 4       1
# Thu, Dec 19      1
# Thu, Dec 21      1
# Thu, Dec 22      1
# Thu, Dec 23      3
# Thu, Dec 26      5
# Thu, Dec 28      7
# Thu, Dec 29      5
# Thu, Dec 30      7
# Thu, Jan 2       3
# Thu, Jan 9       2
# Thu, Nov 10      4
# Thu, Nov 11      2
# Thu, Nov 14      2
# Thu, Nov 16      2
# Thu, Nov 17      2
# Thu, Nov 18      2
# Thu, Nov 2       7
# Thu, Nov 21      1
# Thu, Nov 23      2
# Thu, Nov 24      2
# Thu, Nov 25      3
# Thu, Nov 28      2
# Thu, Nov 3       2
# Thu, Nov 4       2
# Thu, Nov 7       4
# Thu, Nov 9       4
# Thu, Oct 10      6
# Thu, Oct 12      4
# Thu, Oct 13      4
# Thu, Oct 14      4
# Thu, Oct 17      4
# Thu, Oct 19      4
# Thu, Oct 20      4
# Thu, Oct 21      7
# Thu, Oct 24      4
# Thu, Oct 26      4
# Thu, Oct 27      5
# Thu, Oct 28      4
# Thu, Oct 3       4
# Thu, Oct 31      2
# Thu, Oct 5       4
# Thu, Oct 7       4
# Thu, Sep 1       1
# Thu, Sep 12      2
# Thu, Sep 14      2
# Thu, Sep 16      2
# Thu, Sep 19      2
# Thu, Sep 21      2
# Thu, Sep 22      4
# Thu, Sep 26      2
# Thu, Sep 28      6
# Thu, Sep 29      2
# Thu, Sep 30      2
# Tue, Dec 17      1
# Tue, Dec 19      2
# Tue, Dec 20      2
# Tue, Dec 21      4
# Tue, Dec 26      3
# Tue, Dec 27      6
# Tue, Dec 28      7
# Tue, Dec 31      8
# Tue, Jan 4       2
# Tue, Nov 1       4
# Tue, Nov 12      6
# Tue, Nov 14      6
# Tue, Nov 15      4
# Tue, Nov 16      6
# Tue, Nov 19      6
# Tue, Nov 2       6
# Tue, Nov 21      4
# Tue, Nov 22      4
# Tue, Nov 23      4
# Tue, Nov 26      4
# Tue, Nov 5       4
# Tue, Nov 7       6
# Tue, Nov 8       6
# Tue, Nov 9       6
# Tue, Oct 10      4
# Tue, Oct 15      6
# Tue, Oct 17      6
# Tue, Oct 22      4
# Tue, Oct 24      4
# Tue, Oct 29      6
# Tue, Oct 31      4
# Tue, Oct 8       2
# Wed, Dec 18      3
# Wed, Dec 21      1
# Wed, Dec 22      1
# Wed, Dec 27      5
# Wed, Dec 28      6
# Wed, Dec 29      5
# Wed, Jan 1       2
# Wed, Nov 1       4
# Wed, Nov 10      6
# Wed, Nov 13      6
# Wed, Nov 15      4
# Wed, Nov 16      6
# Wed, Nov 17      4
# Wed, Nov 2       4
# Wed, Nov 20      4
# Wed, Nov 3       4
# Wed, Nov 6       4
# Wed, Nov 8       6
# Wed, Nov 9       6
# Wed, Oct 11      4
# Wed, Oct 12      2
# Wed, Oct 16      4
# Wed, Oct 18      4
# Wed, Oct 23      4
# Wed, Oct 25      4
# Wed, Oct 30      4
# Wed, Oct 4       4
# Wed, Oct 5       2
# Wed, Oct 9       2
# Name: count, dtype: int64

# %%
unique_date = df['date'].unique()
unique_date = sorted(unique_date)
unique_date
# Out:
# ['Fri, Dec 1',
#  'Fri, Dec 16',
#  'Fri, Dec 17',
#  'Fri, Dec 2',
#  'Fri, Dec 20',
#  'Fri, Dec 22',
#  'Fri, Dec 23',
#  'Fri, Dec 27',
#  'Fri, Dec 29',
#  'Fri, Dec 3',
#  'Fri, Dec 30',
#  'Fri, Dec 31',
#  'Fri, Dec 6',
#  'Fri, Jan 10',
#  'Fri, Jan 3',
#  'Fri, Nov 1',
#  'Fri, Nov 10',
#  'Fri, Nov 11',
#  'Fri, Nov 12',
#  'Fri, Nov 15',
#  'Fri, Nov 17',
#  'Fri, Nov 18',
#  'Fri, Nov 19',
#  'Fri, Nov 22',
#  'Fri, Nov 24',
#  'Fri, Nov 25',
#  'Fri, Nov 26',
#  'Fri, Nov 29',
#  'Fri, Nov 3',
#  'Fri, Nov 4',
#  'Fri, Nov 5',
#  'Fri, Nov 8',
#  'Fri, Oct 1',
#  'Fri, Oct 11',
#  'Fri, Oct 13',
#  'Fri, Oct 14',
#  'Fri, Oct 15',
#  'Fri, Oct 18',
#  'Fri, Oct 20',
#  'Fri, Oct 21',
#  'Fri, Oct 22',
#  'Fri, Oct 25',
#  'Fri, Oct 27',
#  'Fri, Oct 28',
#  'Fri, Oct 29',
#  'Fri, Oct 4',
#  'Fri, Oct 6',
#  'Fri, Oct 7',
#  'Fri, Oct 8',
#  'Fri, Sep 1',
#  'Fri, Sep 10',
#  'Fri, Sep 13',
#  'Fri, Sep 15',
#  'Fri, Sep 16',
#  'Fri, Sep 17',
#  'Fri, Sep 2',
#  'Fri, Sep 20',
#  'Fri, Sep 22',
#  'Fri, Sep 23',
#  'Fri, Sep 24',
#  'Fri, Sep 27',
#  'Fri, Sep 29',
#  'Fri, Sep 30',
#  'Fri, Sep 6',
#  'Fri, Sep 8',
#  'Fri, Sep 9',
#  'Mon, Dec 18',
#  'Mon, Dec 20',
#  'Mon, Dec 23',
#  'Mon, Dec 26',
#  'Mon, Dec 27',
#  'Mon, Dec 30',
#  'Mon, Jan 1',
#  'Mon, Jan 10',
#  'Mon, Jan 2',
#  'Mon, Jan 20',
#  'Mon, Jan 8',
#  'Mon, Jan 9',
#  'Mon, Sep 2',
#  'Sat, Aug 31',
#  'Sat, Dec 10',
#  'Sat, Dec 11',
#  'Sat, Dec 14',
#  'Sat, Dec 16',
#  'Sat, Dec 17',
#  'Sat, Dec 18',
#  'Sat, Dec 2',
#  'Sat, Dec 21',
#  'Sat, Dec 23',
#  'Sat, Dec 24',
#  'Sat, Dec 25',
#  'Sat, Dec 28',
#  'Sat, Dec 3',
#  'Sat, Dec 30',
#  'Sat, Dec 31',
#  'Sat, Dec 4',
#  'Sat, Dec 7',
#  'Sat, Dec 9',
#  'Sat, Jan 1',
#  'Sat, Jan 4',
#  'Sat, Nov 11',
#  'Sat, Nov 12',
#  'Sat, Nov 13',
#  'Sat, Nov 16',
#  'Sat, Nov 18',
#  'Sat, Nov 19',
#  'Sat, Nov 2',
#  'Sat, Nov 20',
#  'Sat, Nov 23',
#  'Sat, Nov 25',
#  'Sat, Nov 26',
#  'Sat, Nov 27',
#  'Sat, Nov 30',
#  'Sat, Nov 4',
#  'Sat, Nov 5',
#  'Sat, Nov 6',
#  'Sat, Nov 9',
#  'Sat, Oct 1',
#  'Sat, Oct 12',
#  'Sat, Oct 14',
#  'Sat, Oct 15',
#  'Sat, Oct 16',
#  'Sat, Oct 19',
#  'Sat, Oct 2',
#  'Sat, Oct 21',
#  'Sat, Oct 22',
#  'Sat, Oct 23',
#  'Sat, Oct 26',
#  'Sat, Oct 28',
#  'Sat, Oct 29',
#  'Sat, Oct 30',
#  'Sat, Oct 5',
#  'Sat, Oct 7',
#  'Sat, Oct 8',
#  'Sat, Oct 9',
#  'Sat, Sep 10',
#  'Sat, Sep 11',
#  'Sat, Sep 14',
#  'Sat, Sep 16',
#  'Sat, Sep 17',
#  'Sat, Sep 18',
#  'Sat, Sep 2',
#  'Sat, Sep 21',
#  'Sat, Sep 23',
#  'Sat, Sep 24',
#  'Sat, Sep 25',
#  'Sat, Sep 28',
#  'Sat, Sep 3',
#  'Sat, Sep 30',
#  'Sat, Sep 4',
#  'Sat, Sep 7',
#  'Sat, Sep 9',
#  'Sun, Sep 19',
#  'Sun, Sep 3',
#  'Sun, Sep 4',
#  'Thu, Dec 19',
#  'Thu, Dec 21',
#  'Thu, Dec 22',
#  'Thu, Dec 23',
#  'Thu, Dec 26',
#  'Thu, Dec 28',
#  'Thu, Dec 29',
#  'Thu, Dec 30',
#  'Thu, Jan 2',
#  'Thu, Jan 9',
#  'Thu, Nov 10',
#  'Thu, Nov 11',
#  'Thu, Nov 14',
#  'Thu, Nov 16',
#  'Thu, Nov 17',
#  'Thu, Nov 18',
#  'Thu, Nov 2',
#  'Thu, Nov 21',
#  'Thu, Nov 23',
#  'Thu, Nov 24',
#  'Thu, Nov 25',
#  'Thu, Nov 28',
#  'Thu, Nov 3',
#  'Thu, Nov 4',
#  'Thu, Nov 7',
#  'Thu, Nov 9',
#  'Thu, Oct 10',
#  'Thu, Oct 12',
#  'Thu, Oct 13',
#  'Thu, Oct 14',
#  'Thu, Oct 17',
#  'Thu, Oct 19',
#  'Thu, Oct 20',
#  'Thu, Oct 21',
#  'Thu, Oct 24',
#  'Thu, Oct 26',
#  'Thu, Oct 27',
#  'Thu, Oct 28',
#  'Thu, Oct 3',
#  'Thu, Oct 31',
#  'Thu, Oct 5',
#  'Thu, Oct 7',
#  'Thu, Sep 1',
#  'Thu, Sep 12',
#  'Thu, Sep 14',
#  'Thu, Sep 16',
#  'Thu, Sep 19',
#  'Thu, Sep 21',
#  'Thu, Sep 22',
#  'Thu, Sep 26',
#  'Thu, Sep 28',
#  'Thu, Sep 29',
#  'Thu, Sep 30',
#  'Tue, Dec 17',
#  'Tue, Dec 19',
#  'Tue, Dec 20',
#  'Tue, Dec 21',
#  'Tue, Dec 26',
#  'Tue, Dec 27',
#  'Tue, Dec 28',
#  'Tue, Dec 31',
#  'Tue, Jan 4',
#  'Tue, Nov 1',
#  'Tue, Nov 12',
#  'Tue, Nov 14',
#  'Tue, Nov 15',
#  'Tue, Nov 16',
#  'Tue, Nov 19',
#  'Tue, Nov 2',
#  'Tue, Nov 21',
#  'Tue, Nov 22',
#  'Tue, Nov 23',
#  'Tue, Nov 26',
#  'Tue, Nov 5',
#  'Tue, Nov 7',
#  'Tue, Nov 8',
#  'Tue, Nov 9',
#  'Tue, Oct 10',
#  'Tue, Oct 15',
#  'Tue, Oct 17',
#  'Tue, Oct 22',
#  'Tue, Oct 24',
#  'Tue, Oct 29',
#  'Tue, Oct 31',
#  'Tue, Oct 8',
#  'Wed, Dec 18',
#  'Wed, Dec 21',
#  'Wed, Dec 22',
#  'Wed, Dec 27',
#  'Wed, Dec 28',
#  'Wed, Dec 29',
#  'Wed, Jan 1',
#  'Wed, Nov 1',
#  'Wed, Nov 10',
#  'Wed, Nov 13',
#  'Wed, Nov 15',
#  'Wed, Nov 16',
#  'Wed, Nov 17',
#  'Wed, Nov 2',
#  'Wed, Nov 20',
#  'Wed, Nov 3',
#  'Wed, Nov 6',
#  'Wed, Nov 8',
#  'Wed, Nov 9',
#  'Wed, Oct 11',
#  'Wed, Oct 12',
#  'Wed, Oct 16',
#  'Wed, Oct 18',
#  'Wed, Oct 23',
#  'Wed, Oct 25',
#  'Wed, Oct 30',
#  'Wed, Oct 4',
#  'Wed, Oct 5',
#  'Wed, Oct 9']

# %%
df['win_loss'].isna().sum()
# Out:
# np.int64(0)

# %%
df['win_loss'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['win_loss'].value_counts().sort_index()
# Out:
# win_loss
# L    2841
# W    2805
# Name: count, dtype: int64

# %%
df['OT'].isna().sum()
# Out:
# np.int64(0)

# %%
df['OT'].unique()
# Out:
# array([ True, False])

# %%
df['OT'].value_counts().sort_index()
# Out:
# OT
# False    5391
# True      255
# Name: count, dtype: int64

# %%
df['OT_num'].isna().sum()
# Out:
# np.int64(5391)

# %%
df['OT_num'].unique()
# Out:
# array([' ', nan, '2', '3', '4', '8', '6', '9'], dtype=object)

# %%
df['OT_num'].value_counts().sort_index()
# Out:
# OT_num
#      164
# 2     65
# 3      8
# 4     12
# 6      2
# 8      2
# 9      2
# Name: count, dtype: int64

# %%
df['home_game'].isna().sum()
# Out:
# np.int64(0)

# %%
df['home_game'].unique()
# Out:
# array([ True, False])

# %%
df['home_game'].value_counts().sort_index()
# Out:
# home_game
# False    2652
# True     2994
# Name: count, dtype: int64

# %%
df['CONF'].isna().sum()
# Out:
# np.int64(0)

# %%
df['CONF'].unique()
# Out:
# array(['Mountain West', 'MAC', 'SEC', 'Pac-12', 'FBS Indep.', 'Big 12',
#        'ACC', 'CUSA', 'American', 'Sun Belt', 'Big Ten'], dtype=object)

# %%
df['CONF'].value_counts().sort_index()
# Out:
# CONF
# ACC              628
# American         532
# Big 12           560
# Big Ten          676
# CUSA             474
# FBS Indep.       205
# MAC              521
# Mountain West    484
# Pac-12           419
# SEC              644
# Sun Belt         503
# Name: count, dtype: int64

# %%
df['SOR'].isna().sum()
# Out:
# np.int64(0)

# %%
df['SOR'].unique()
# Out:
# array([ 33, 127,   2, 122,  49,  14,  44,  48,  95,   7,  55,  75, 111,
#        118,  53, 108,   6,  34,  81, 115, 109,  58,  85,  67, 102, 130,
#         68,  30,   1, 116,  57,  92,  96,  17,  73,  93,  16,  38, 104,
#         31,  88,  19,  72,  11, 120,  70,  51,  78,  45,  82,  35,  79,
#          3,   5,  80,  28,  41,  71,  89,  23,  84, 119,  69, 101,  60,
#        100,  10, 123,   8,   4,  98,  12,  20,  59,  37,  21,  18, 106,
#         77,  24,  99,  50, 107,  43, 114, 124,  91,  64, 117,  46,  56,
#         29, 112,  94, 103, 110,  66,  47,  42,  36, 105, 121,  87,  27,
#         32,  90,  26,  74,  15,  97,  54,  61,  62,  22,  86,  52,  39,
#        113, 128,  25,  40,  76,  63, 129, 126,  13,  83,  65, 125,   9,
#        132, 133, 131, 134])

# %%
df['SOR'].value_counts().sort_index()
# Out:
# SOR
# 1      52
# 2      53
# 3      53
# 4      47
# 5      48
# 6      49
# 7      45
# 8      47
# 9      47
# 10     47
# 11     46
# 12     46
# 13     41
# 14     45
# 15     47
# 16     47
# 17     45
# 18     43
# 19     46
# 20     46
# 21     43
# 22     47
# 23     44
# 24     44
# 25     46
# 26     44
# 27     46
# 28     46
# 29     45
# 30     44
# 31     44
# 32     44
# 33     47
# 34     44
# 35     42
# 36     43
# 37     43
# 38     46
# 39     34
# 40     45
# 41     45
# 42     42
# 43     45
# 44     39
# 45     45
# 46     43
# 47     44
# 48     45
# 49     46
# 50     45
# 51     42
# 52     44
# 53     45
# 54     44
# 55     45
# 56     42
# 57     42
# 58     39
# 59     43
# 60     45
# 61     41
# 62     43
# 63     43
# 64     42
# 65     31
# 66     43
# 67     44
# 68     41
# 69     44
# 70     41
# 71     42
# 72     44
# 73     43
# 74     43
# 75     44
# 76     41
# 77     45
# 78     43
# 79     42
# 80     44
# 81     44
# 82     41
# 83     44
# 84     42
# 85     45
# 86     41
# 87     43
# 88     32
# 89     41
# 90     41
# 91     44
# 92     42
# 93     40
# 94     39
# 95     41
# 96     42
# 97     42
# 98     38
# 99     43
# 100    43
# 101    39
# 102    41
# 103    40
# 104    43
# 105    41
# 106    40
# 107    40
# 108    41
# 109    40
# 110    42
# 111    40
# 112    39
# 113    41
# 114    40
# 115    39
# 116    41
# 117    39
# 118    42
# 119    40
# 120    43
# 121    39
# 122    41
# 123    39
# 124    41
# 125    40
# 126    39
# 127    40
# 128    40
# 129    38
# 130    40
# 131    27
# 132    19
# 133    19
# 134    10
# Name: count, dtype: int64

# %%
df['GC'].isna().sum()
# Out:
# np.int64(0)

# %%
df['GC'].unique()
# Out:
# array([ 24, 118,   2, 110,  61,  20,  39,  29,  93,   6,  36,  70, 112,
#         71, 117,   5,  47,  80, 107, 111,  74, 105,  45,  99,  53,  37,
#          1, 115,  72,  82,  94,  27,  60,  83,  33,  32,  95,  35,  92,
#         15,  77,  34,  88,  38,  31,  65,  57,  76,  43,  87,   3,  19,
#         98,  22,  54,  79,  89,  26,  40,  63, 116,  91, 103,   9,   4,
#         10, 104,   8,  23,  51,  14,  13,  25, 106,  81,  59, 114,  52,
#         97,  75, 102, 100,  66,  18,  28,  30,  78, 108,  96,  67,  46,
#         58,  41, 109, 101,  85,  17,  86,  90,  62,  68,  11,  84,  49,
#         64,  44,   7, 113, 120,  73, 119,  12,  55,  56,  48,  69,  42,
#         50,  21,  16, 122, 124, 121, 123])

# %%
df['GC'].value_counts().sort_index()
# Out:
# GC
# 1       52
# 2       52
# 3       49
# 4       51
# 5       49
# 6       46
# 7       47
# 8       48
# 9       43
# 10      46
# 11      45
# 12      46
# 13      47
# 14      43
# 15      44
# 16      43
# 17      46
# 18      46
# 19      46
# 20      43
# 21      44
# 22      44
# 23      48
# 24      46
# 25      45
# 26      46
# 27      46
# 28      45
# 29      45
# 30      42
# 31      46
# 32      47
# 33      44
# 34      43
# 35      43
# 36      44
# 37      43
# 38      46
# 39      43
# 40      45
# 41      39
# 42      45
# 43      42
# 44      41
# 45      43
# 46      44
# 47      45
# 48      46
# 49      45
# 50      45
# 51      46
# 52      43
# 53      41
# 54      42
# 55      32
# 56      44
# 57      44
# 58      42
# 59      42
# 60      41
# 61      46
# 62      47
# 63      38
# 64      44
# 65      44
# 66      44
# 67      42
# 68      44
# 69      40
# 70      43
# 71      41
# 72      40
# 73      40
# 74      32
# 75      45
# 76      44
# 77      44
# 78      44
# 79      41
# 80      44
# 81      42
# 82      43
# 83      43
# 84      41
# 85      42
# 86      33
# 87      44
# 88      41
# 89      43
# 90      42
# 91      43
# 92      45
# 93      41
# 94      40
# 95      44
# 96      41
# 97      42
# 98      42
# 99      42
# 100     41
# 101     41
# 102     41
# 103     41
# 104     39
# 105     41
# 106     39
# 107     41
# 108     40
# 109     40
# 110     39
# 111     42
# 112     42
# 113     41
# 114     45
# 115     39
# 116     43
# 117     48
# 118    148
# 119     28
# 120    137
# 121     19
# 122    128
# 123     11
# 124    112
# Name: count, dtype: int64

# %%
df['FPI'].isna().sum()
# Out:
# np.int64(0)

# %%
df['FPI'].unique()
# Out:
# array([ 66, 128,   2, 106,  39,  21,  61,  20, 103,  15,  38,  71, 123,
#         99,  79, 117,  10,  45,  89,  97, 113,  81,  95,  34,  92, 126,
#         51,  53,   1, 111,  83,  82, 102,  37,  67,  84,  32,   9, 114,
#         35, 100,  28,  56,  48, 104,  46,  42,  70,  63,  80,  23,  85,
#          4,  19,  87,  27,  36,  78, 101,  16,  29, 124,  43,  96,  93,
#         94,   6, 115,   3,   7, 105,  18,  30,  52,  17,  12,  25, 122,
#         86,  72, 108,  44, 109,  69, 107, 116,  91,  68, 125,  26,  24,
#         14, 119,  65,  98,  90,  76,  60,  55,  31, 120, 112,  58,  11,
#         74, 110,  57,  64,  22,  62,  49,  41,  75,  13,  88,  73,  54,
#        127,  40,  33, 131, 129, 121,  50, 118,  47,   5,  77,   8,  59,
#        133, 130, 134, 132])

# %%
df['FPI'].value_counts().sort_index()
# Out:
# FPI
# 1      52
# 2      51
# 3      50
# 4      48
# 5      44
# 6      49
# 7      48
# 8      44
# 9      45
# 10     46
# 11     46
# 12     48
# 13     48
# 14     45
# 15     45
# 16     45
# 17     46
# 18     45
# 19     43
# 20     46
# 21     45
# 22     47
# 23     43
# 24     45
# 25     45
# 26     45
# 27     46
# 28     45
# 29     44
# 30     42
# 31     43
# 32     48
# 33     32
# 34     46
# 35     43
# 36     45
# 37     45
# 38     42
# 39     48
# 40     44
# 41     44
# 42     43
# 43     42
# 44     44
# 45     44
# 46     45
# 47     41
# 48     43
# 49     44
# 50     45
# 51     43
# 52     42
# 53     42
# 54     47
# 55     44
# 56     44
# 57     46
# 58     45
# 59     43
# 60     45
# 61     41
# 62     45
# 63     43
# 64     41
# 65     31
# 66     34
# 67     43
# 68     41
# 69     44
# 70     42
# 71     43
# 72     47
# 73     44
# 74     44
# 75     42
# 76     39
# 77     45
# 78     44
# 79     43
# 80     41
# 81     38
# 82     41
# 83     41
# 84     41
# 85     44
# 86     43
# 87     43
# 88     40
# 89     42
# 90     44
# 91     43
# 92     41
# 93     39
# 94     42
# 95     44
# 96     43
# 97     41
# 98     38
# 99     42
# 100    44
# 101    39
# 102    40
# 103    43
# 104    40
# 105    38
# 106    40
# 107    41
# 108    43
# 109    38
# 110    41
# 111    42
# 112    42
# 113    36
# 114    41
# 115    39
# 116    40
# 117    41
# 118    41
# 119    41
# 120    39
# 121    40
# 122    42
# 123    39
# 124    42
# 125    37
# 126    45
# 127    37
# 128    41
# 129    39
# 130    37
# 131    29
# 132    18
# 133    21
# 134    10
# Name: count, dtype: int64

# %%
df['SOS'].isna().sum()
# Out:
# np.int64(0)

# %%
df['SOS'].unique()
# Out:
# array([110,  67,   1,  71,  61,   2,  86,   4, 105,  25,  82,  72, 114,
#        127, 119, 128,  54, 130,  48, 104,  77,  87, 103,  17, 112, 125,
#         41,  95,   3, 100,  88,  12,  99,  78,  53,   7,  23,  24,  34,
#         39,  85,  32, 106, 101,  98,  50,  14, 113,  21, 115,  36,  89,
#          5,  13, 111,  44,  29,  22,  65,  63,  11,  94,  42, 126,  73,
#         37,  43, 129,  27,  18, 109,  19,   8,  69,  10,  57,  15,  93,
#         20, 102, 123,  84, 116,   9,  66,  74,  58,  28,  96,   6,  31,
#         52, 117, 108, 122,  51,  33,  46,  75,  76,  79,  91,  56,  47,
#        107, 120, 118,  60,  45,  62,  26,  92,  64,  35, 124, 131, 121,
#         83,  80,  40,  16,  90,  55,  97,  30,  38,  81,  68,  49, 132,
#         70,  59, 133, 134])

# %%
df['SOS'].value_counts().sort_index()
# Out:
# SOS
# 1      49
# 2      49
# 3      46
# 4      50
# 5      47
# 6      45
# 7      45
# 8      43
# 9      46
# 10     45
# 11     44
# 12     46
# 13     44
# 14     44
# 15     45
# 16     43
# 17     45
# 18     45
# 19     46
# 20     45
# 21     45
# 22     42
# 23     47
# 24     44
# 25     42
# 26     45
# 27     47
# 28     46
# 29     42
# 30     44
# 31     44
# 32     44
# 33     46
# 34     45
# 35     48
# 36     43
# 37     43
# 38     42
# 39     44
# 40     42
# 41     44
# 42     44
# 43     47
# 44     44
# 45     42
# 46     44
# 47     45
# 48     44
# 49     42
# 50     45
# 51     45
# 52     43
# 53     43
# 54     42
# 55     39
# 56     42
# 57     43
# 58     44
# 59     39
# 60     44
# 61     45
# 62     44
# 63     45
# 64     42
# 65     45
# 66     41
# 67     42
# 68     44
# 69     43
# 70     44
# 71     40
# 72     46
# 73     41
# 74     41
# 75     42
# 76     44
# 77     42
# 78     44
# 79     40
# 80     42
# 81     35
# 82     44
# 83     40
# 84     39
# 85     42
# 86     39
# 87     40
# 88     38
# 89     43
# 90     39
# 91     40
# 92     43
# 93     43
# 94     41
# 95     40
# 96     44
# 97     39
# 98     42
# 99     33
# 100    41
# 101    41
# 102    42
# 103    40
# 104    39
# 105    42
# 106    39
# 107    42
# 108    45
# 109    42
# 110    45
# 111    45
# 112    39
# 113    42
# 114    40
# 115    32
# 116    39
# 117    36
# 118    43
# 119    42
# 120    44
# 121    43
# 122    41
# 123    43
# 124    43
# 125    42
# 126    42
# 127    44
# 128    40
# 129    42
# 130    42
# 131    31
# 132    21
# 133    18
# 134    11
# Name: count, dtype: int64

# %%
df['AVGWP'].isna().sum()
# Out:
# np.int64(0)

# %%
df['AVGWP'].unique()
# Out:
# array([  6, 125,   3, 122,  63,  41,  21,  58,  80,   7,  29,  65, 100,
#        107,  44,  97,   2,   5, 102, 106, 115,  66,  87,  62,  89, 124,
#         74,  19,   1, 111,  60, 110,  85,  10,  82, 119,  54,  56, 123,
#         48,  83,  15,  49,  12,  81,  46,  52,  34,  79,  50,  57,  67,
#          4,  39,  84,  26,  71,  91, 104,  30,  76, 121,  70,  93,  78,
#        120,  11,  98,   8,  23,  90,  16,  37,  59,  33,   9,  47, 109,
#        103,  24, 101,  45,  75,  95, 116, 105, 118,  96, 128,  27,  55,
#         28, 112,  35,  94, 114,  69,  31,  42,  36, 113, 108,  99,  18,
#         61,  64,  25,  73,  13,  86,  77,  43,  32,  14,  92,  53, 131,
#        127,  22,  88,  72,  40, 126,  20, 117, 130,  51,  17, 129,  38,
#        132,  68, 133, 134])

# %%
df['AVGWP'].value_counts().sort_index()
# Out:
# AVGWP
# 1      52
# 2      47
# 3      52
# 4      48
# 5      51
# 6      43
# 7      48
# 8      49
# 9      44
# 10     46
# 11     46
# 12     44
# 13     46
# 14     46
# 15     46
# 16     45
# 17     44
# 18     44
# 19     44
# 20     42
# 21     44
# 22     40
# 23     47
# 24     46
# 25     46
# 26     45
# 27     44
# 28     44
# 29     42
# 30     46
# 31     44
# 32     43
# 33     44
# 34     42
# 35     44
# 36     43
# 37     45
# 38     34
# 39     45
# 40     44
# 41     43
# 42     45
# 43     44
# 44     46
# 45     43
# 46     46
# 47     46
# 48     46
# 49     40
# 50     42
# 51     44
# 52     43
# 53     44
# 54     35
# 55     44
# 56     46
# 57     41
# 58     47
# 59     46
# 60     43
# 61     43
# 62     42
# 63     46
# 64     42
# 65     41
# 66     44
# 67     44
# 68     34
# 69     47
# 70     42
# 71     43
# 72     42
# 73     43
# 74     40
# 75     39
# 76     40
# 77     43
# 78     44
# 79     44
# 80     46
# 81     39
# 82     42
# 83     47
# 84     42
# 85     43
# 86     40
# 87     42
# 88     43
# 89     40
# 90     40
# 91     45
# 92     37
# 93     41
# 94     40
# 95     43
# 96     42
# 97     41
# 98     40
# 99     43
# 100    41
# 101    41
# 102    40
# 103    42
# 104    42
# 105    39
# 106    42
# 107    43
# 108    40
# 109    41
# 110    40
# 111    41
# 112    42
# 113    41
# 114    38
# 115    39
# 116    41
# 117    40
# 118    43
# 119    40
# 120    39
# 121    41
# 122    38
# 123    41
# 124    42
# 125    40
# 126    40
# 127    39
# 128    40
# 129    38
# 130    38
# 131    32
# 132    19
# 133    21
# 134    10
# Name: count, dtype: int64

# %%
df['AP_rank'].isna().sum()
# Out:
# np.int64(4485)

# %%
df['AP_rank'].unique()
# Out:
# array([nan,  3., 12., 14.,  2., 21., 25.,  1., 20., 19., 18., 24.,  9.,
#         5.,  8.,  6., 11., 15.,  7., 22., 23., 13., 16., 10.,  4., 17.])

# %%
unique_AP_rank = df['AP_rank'].unique()
unique_AP_rank = sorted(unique_AP_rank)
unique_AP_rank
# Out:
# [np.float64(nan),
#  np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(5.0),
#  np.float64(6.0),
#  np.float64(7.0),
#  np.float64(8.0),
#  np.float64(9.0),
#  np.float64(10.0),
#  np.float64(11.0),
#  np.float64(12.0),
#  np.float64(13.0),
#  np.float64(14.0),
#  np.float64(15.0),
#  np.float64(16.0),
#  np.float64(17.0),
#  np.float64(18.0),
#  np.float64(19.0),
#  np.float64(20.0),
#  np.float64(21.0),
#  np.float64(22.0),
#  np.float64(23.0),
#  np.float64(24.0),
#  np.float64(25.0)]

# %%
df['AP_rank'].value_counts().sort_index()
# Out:
# AP_rank
# 1.0     49
# 2.0     57
# 3.0     51
# 4.0     45
# 5.0     50
# 6.0     46
# 7.0     48
# 8.0     45
# 9.0     43
# 10.0    49
# 11.0    47
# 12.0    45
# 13.0    45
# 14.0    44
# 15.0    44
# 16.0    46
# 17.0    46
# 18.0    45
# 19.0    45
# 20.0    45
# 21.0    42
# 22.0    47
# 23.0    43
# 24.0    47
# 25.0    47
# Name: count, dtype: int64

# %%
df['opponent_rank'].isna().sum()
# Out:
# np.int64(4450)

# %%
df['opponent_rank'].unique()
# Out:
# array([nan, 13., 25., 21., 24.,  9., 15.,  3., 22., 23.,  1.,  8., 10.,
#        19.,  5., 20., 14., 18., 12.,  7., 11.,  2., 16.,  6.,  4., 17.])

# %%
df['opponent_rank'].value_counts().sort_index()
# Out:
# opponent_rank
# 1.0     52
# 2.0     58
# 3.0     51
# 4.0     46
# 5.0     50
# 6.0     48
# 7.0     47
# 8.0     46
# 9.0     41
# 10.0    48
# 11.0    49
# 12.0    44
# 13.0    48
# 14.0    46
# 15.0    55
# 16.0    53
# 17.0    44
# 18.0    48
# 19.0    45
# 20.0    41
# 21.0    47
# 22.0    44
# 23.0    43
# 24.0    46
# 25.0    56
# Name: count, dtype: int64

# %%
df['rank_change'].isna().sum()
# Out:
# np.int64(175)

# %%
df['rank_change'].unique()
# Out:
# array([  0.,  -1.,   7.,  -9.,  -4.,  -3.,  -6.,   9.,   3.,   6.,  -2.,
#          1.,   5., -11.,   2.,  -5.,  10.,   4.,   8.,  -8.,  11.,  -7.,
#        -12.,  24.,  19.,  15.,  21.,  23.,  nan,  13., -10.,  16.,  12.,
#         17.])

# %%
df['rank_change'].value_counts().sort_index()
# Out:
# rank_change
# -12.0       1
# -11.0       4
# -10.0       4
# -9.0       10
# -8.0        9
# -7.0       18
# -6.0       30
# -5.0       41
# -4.0       57
# -3.0      115
# -2.0      167
# -1.0      211
#  0.0     4426
#  1.0       57
#  2.0       34
#  3.0       44
#  4.0       45
#  5.0       42
#  6.0       36
#  7.0       31
#  8.0       21
#  9.0       22
#  10.0      14
#  11.0      13
#  12.0       8
#  13.0       4
#  15.0       1
#  16.0       1
#  17.0       1
#  19.0       1
#  21.0       1
#  23.0       1
#  24.0       1
# Name: count, dtype: int64

# %%
unique_rank_change = df['rank_change'].unique()
unique_rank_change = sorted(unique_rank_change)
unique_rank_change
# Out:
# [np.float64(-12.0),
#  np.float64(-11.0),
#  np.float64(-10.0),
#  np.float64(-9.0),
#  np.float64(-8.0),
#  np.float64(-7.0),
#  np.float64(-6.0),
#  np.float64(-5.0),
#  np.float64(-4.0),
#  np.float64(-3.0),
#  np.float64(-2.0),
#  np.float64(-1.0),
#  np.float64(0.0),
#  np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(5.0),
#  np.float64(6.0),
#  np.float64(7.0),
#  np.float64(8.0),
#  np.float64(9.0),
#  np.float64(10.0),
#  np.float64(11.0),
#  np.float64(12.0),
#  np.float64(13.0),
#  np.float64(15.0),
#  np.float64(16.0),
#  np.float64(17.0),
#  np.float64(19.0),
#  np.float64(21.0),
#  np.float64(23.0),
#  np.float64(24.0),
#  np.float64(nan)]
